# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
k=5
sigma =0.6
n =50
x,y = make_blobs(n_samples=n,centers=k,random_state=0,cluster_std=sigma)

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %%
def Loyd(f_init):
  iteration=0

  centroids_  = f_init()
  centroids_star = []
  distance = np.zeros((n,k))
  list_cluster= []
  for c in centroids :
    cluster = [c]
    list_cluster.append(cluster)
  
  
  while(np.all((centroids==centroids_star))):

    distance = calcul_distance(x,centroids_)
    nearst_centroid = []
    for i,xi in enumerate(x):    
      nearst_centroid = np.argmin(distance[i,:])
      list_cluster.append()

    if iteration>1000:
      break


def asign_cluster ():
    


def calcul_distance(x,cent):

  def _distnace(x,cent):
    dist = []
    for c in cent:
      dist=np.linalog.norm(xi-c)
    return dist

  distance = []
  for i,xi in enumerate(x):
    distance.append([np.linalog.norm(xi-c) for c in cent])
  return _distance
